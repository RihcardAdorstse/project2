# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
from matplotlib.axes._axes import Axes

# %%
# %matplotlib inline

# %%
style.use('seaborn-poster')
style.use('ggplot')
plt.rc('figure')

# %%
housedata = pd.read_csv('C:\\Users\\Richard\\Desktop\\blossom\\housedata\\data.csv')

# %%
housedata.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
housedata.shape
# Out:
# (4600, 18)

# %%
numerical_var = ['price', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']

# %%
list(enumerate(numerical_var))
# Out:
# [(0, 'price'),
#  (1, 'sqft_living'),
#  (2, 'sqft_lot'),
#  (3, 'sqft_above'),
#  (4, 'sqft_basement')]

# %%
housedata[numerical_var].describe()
# Out:
#               price   sqft_living      sqft_lot   sqft_above  sqft_basement
# count  4.600000e+03   4600.000000  4.600000e+03  4600.000000    4600.000000
# mean   5.519630e+05   2139.346957  1.485252e+04  1827.265435     312.081522
# std    5.638347e+05    963.206916  3.588444e+04   862.168977     464.137228
# min    0.000000e+00    370.000000  6.380000e+02   370.000000       0.000000
# 25%    3.228750e+05   1460.000000  5.000750e+03  1190.000000       0.000000
# 50%    4.609435e+05   1980.000000  7.683000e+03  1590.000000       0.000000
# 75%    6.549625e+05   2620.000000  1.100125e+04  2300.000000     610.000000
# max    2.659000e+07  13540.000000  1.074218e+06  9410.000000    4820.000000

# %%
even though yr_built annd  yr_renovated are also nurimerical variable, their descriptive statistics arenot meanful inthis context

# %%
fig, axes = plt.subplots(5, 2, figsize = (20,20))
for i, col in enumerate(numerical_var):
    sns.boxplot(housedata[col], ax=axes[i, 0]);
    sns.distplot(housedata[col], kde= True, ax=axes[i, 1],);
        
fig.tight_layout()

# %%
housedata.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
housedata.sample(6)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 3888  2014-07-02 00:00:00  915000.00       3.0        4.5         3850
# 1934  2014-06-05 00:00:00  269000.00       3.0        1.0         1690
# 4439  2014-05-30 00:00:00  237481.25       3.0        2.0         2120
# 3221  2014-06-24 00:00:00  875000.00       4.0        2.5         3220
# 938   2014-05-20 00:00:00  479000.00       3.0        2.5         1260
# 1229  2014-05-23 00:00:00  175000.00       2.0        1.0         1300
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 3888     62726     2.0           0     0          3        3120
# 1934      4250     1.0           0     0          3        1020
# 4439      7560     1.0           0     0          3        2120
# 3221     22588     2.0           0     0          3        3220
# 938        889     3.0           0     0          3        1260
# 1229     44431     1.0           0     0          5        1300
#
# ...

# %%
categorical_var = ['bedrooms', 'bathrooms', 'floors', 'condition', 'city', 'country']

# %%
fig, axes = plt.subplots(2, 3, figsize = (12, 3))
for var, subplot in zip(categorical_var, axes.flatten()):
    housedata[var].value_counts().plot(kind = 'bar', ax = subplot, title = var)

# %%
sns.heatmap(housedata.corr(), annot=True);

# %%
response = housedata['price']

# %%
pretd_response1 = response.mean()
pretd_response1
# Out:
# 551962.9884732141

# %%
pretd_response2 = response.median()
pretd_response2
# Out:
# 460943.46153850004

# %%
pretd_response3 = response.max()
pretd_response3
# Out:
# 26590000.0

# %%
pretd_response4 = response.min()
pretd_response4
# Out:
# 0.0

# %%
pretd_response5 = response.std()
pretd_response5
# Out:
# 563834.7025471417

# %%
nbh_prtd = housedata.groupby([ 'city'])['price'].agg('median')
nbh_prtd.head()
# Out:
# city
# Algona                230000.0
# Auburn                274000.0
# Beaux Arts Village    745000.0
# Bellevue              721500.0
# Black Diamond         255000.0
# Name: price, dtype: float64

# %%
nbh_prtd = housedata.groupby([ 'city', 'country', 'bedrooms', 'bathrooms', 'floors','condition']) \
['price'].agg('median')
nbh_prtd.head()
# Out:
# city    country  bedrooms  bathrooms  floors  condition
# Algona  USA      2.0       1.0        1.0     3            100000.0
#                  3.0       1.0        1.0     4            230000.0
#                            2.0        1.0     3            196440.0
#                  4.0       2.5        2.0     3            262000.0
#                            3.0        2.0     3            248000.0
# Name: price, dtype: float64
